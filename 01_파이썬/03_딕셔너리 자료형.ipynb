# %%
# 딕셔너리 생성
a = {1:"a"}

# 딕셔너리 쌍 추가
a[2] = "b"
a
# Out:
# {1: 'a', 2: 'b'}

# %%
a["name"]="pey"
a
# Out:
# {1: 'a', 2: 'b', 'name': 'pey'}

# %%
a[3]=[1,2,3]
a
# Out:
# {1: 'a', 2: 'b', 'name': 'pey', 3: [1, 2, 3]}

# %%
a["name"]
# Out:
# 'pey'

# %%
shin = {"name":"홍길동", "gender":"female","hobby":"running"}
print(shin["name"])
print(shin["gender"])
print(shin["hobby"])
# Out:
# 홍길동
# female
# running

# %%
listbox=shin.keys()
result=list(listbox)
result
# Out:
# ['name', 'gender', 'hobby']

# %%
list (shin.values())
# Out:
# ['홍길동', 'female', 'running']

# %%
values=shin.values()
result=list(values)
result
# Out:
# ['홍길동', 'female', 'running']

# %%
shin
# Out:
# {'name': '홍길동', 'gender': 'female', 'hobby': 'running'}

# %%
# shin["name"]
shin.get("name")
# Out:
# '홍길동'

# %%
# 해당 key가 딕셔너리 안에 있는지 조사하기 - in
print("name" in shin)
print("email" in shin)
# Out:
# True
# False

# %%
# key로 value값 얻기 - pop
shin={'name': '홍길동', 'gender': 'female', 'hobby': 'running'}
result = shin.pop("hobby")
result
# Out:
# 'running'
